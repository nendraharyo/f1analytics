# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from f1analytics.vizHelper import vizTemplates as vt 
import seaborn as sns
import fastf1

# %%
austriangp_r=fastf1.get_session(2024,'austria','r')
austriangp_r.load()
austriangp_q=fastf1.get_session(2024,'austria','q')
austriangp_s=fastf1.get_session(2024, 'austria', 's')
austriangp_q.load()
austriangp_s.load()
austriangp_sq=fastf1.get_session(2024, 'austria', 'sq')
austriangp_sq.load()

# %%
austriangp_rViz=vt.vizDataRace(austriangp_r)
austriangp_qViz=vt.vizDataQuali(austriangp_q)
austriangp_sViz=vt.vizDataRace(austriangp_s)
austriangp_sqViz=vt.vizDataQuali(austriangp_sq)
# Out:
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# D:\f1analytics\src\f1analytics\vizHelper\vizTemplates.py:334: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   tyreAlphas = pd.concat(
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# D:\f1analytics\src\f1analytics\vizHelper\vizTemplates.py:334: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   tyreAlphas = pd.concat(
# ...

# %%
austriangp_sqViz=vt.vizDataQuali(austriangp_sq)
# Out:
# getting and enriching fastest laps telemetry...
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# ...

# %%
austriangp_rViz.LinePlot(['VER','NOR', 'RUS'],13)

# %%
austriangp_qViz.quadrantAnalysis()

# %%
austriangp_sqViz.quadrantAnalysis()

# %%
austriangp_rViz.LinePlot(['RUS','PIA','SAI','HAM'],13)

# %%
austriangp_rViz.BoxPlot('mean')

# %%
austriangp_rViz.TyreStrats()

# %%
austriangp_rViz.drsGain()

# %%
austriangp_rViz.TyreDeg(['VER','NOR'])

# %%
austriangp_rViz.trackDominance(drvList=['VER','NOR'],mode='average')

# %%
austriangp_qViz.trackDominance(drvList=['VER','NOR'],mode='average')
# Out:
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
