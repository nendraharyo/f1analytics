# %%
# %load_ext autoreload
# %autoreload 2
import fastf1
import pandas as pd
from f1analytics.vizHelper import vizTemplates
import matplotlib.pyplot as plt

# %%
canadagp_q=fastf1.get_session(2024,'canada','q')
canadagp_r=fastf1.get_session(2024,'canada','r')

canadagp_q.load()
canadagp_r.load()

# %%
canadagp_qViz=vizTemplates.vizDataQuali(canadagp_q)
canadagp_rViz=vizTemplates.vizDataRace(canadagp_r)
# Out:
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# /Users/nendra/f1analytics/src/f1analytics/vizHelper/vizTemplates.py:334: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   tyreAlphas = pd.concat(

# %%
canadagp_qViz.quadrantAnalysis()

# %%
canadagp_qViz.clusterAnalysis(mode='avg',min_samp=2,epsVar=0.5)

# %%
canadagp_rViz.clusterAnalysis(mode='avg',min_samp=2,epsVar=0.4)

# %%
canadagp_rViz.TyreStrats()

# %%
canadagp_rViz.BoxPlot()

# %%
canadagp_rViz.TyreDeg()
# Out:
# /Users/nendra/f1analytics/src/f1analytics/vizHelper/vizTemplates.py:1378: RankWarning: Polyfit may be poorly conditioned
#   a, b = np.polyfit(group["TyreLife"], y, 1)

# %%
canadagp_rViz.LinePlot(['VER','NOR','PIA','HAM','RUS','HUL','MAG'])

# %%
canadagp_rViz.LinePlot(['LEC','SAI','PER','VER'])

# %%
canadagp_rViz.trackDominance(xstart=600,ystart=-240,drvList=['RUS','NOR','HAM','VER'],mode='average')
# Out:
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.

# %%
canadagp_rViz.violin()

# %%
canadagp_rViz.deltaTime(['NOR','HAM','RUS'],'VER',range(2,71))
# Out:
# /Users/nendra/f1analytics/.venv/lib/python3.10/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /Users/nendra/f1analytics/.venv/lib/python3.10/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
# /Users/nendra/f1analytics/.venv/lib/python3.10/site-packages/fastf1/utils.py:91: FutureWarning: `utils.delta_time` is considered deprecated and willbe modified or removed in a future release because it hasa tendency to give inaccurate results.
#   warnings.warn("`utils.delta_time` is considered deprecated and will"
