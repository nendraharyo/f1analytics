# %%
#mengimpor modul
from f1analytics.vizHelper import vizTemplates
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import fastf1

fastf1.plotting.setup_mpl()
fastf1.logger.set_log_level("ERROR")

# %% [markdown]
# <H1><strong>Analisis Miami GP 2024</strong></H1>
# <p>Kesulitan Verstappen dan upgrade menyeluruh pada mobil Lando sangat berkontribusi dalam balapan ini. Seperti apa analisisnya?</p>

# %%
#memuat data dan variabel
miamigp_s=fastf1.get_session(2024,'miami','s')
miamigp_s.load()
miamigp_r=fastf1.get_session(2024,'miami','r')
miamigp_r.load()
miamigp_sq=fastf1.get_session(2024,'miami','sq')
miamigp_sq.load()
miamigp_q=fastf1.get_session(2024,'miami','q')
miamigp_q.load()

miamigp_rLS=fastf1.get_session(2023,'miami','r')
miamigp_rLS.load()
miamigp_qLS=fastf1.get_session(2023,'miami','q')
miamigp_qLS.load()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (784.82 MB) /Users/nendra/Library/Caches/fastf1
# core           INFO 	Loading data for Miami Grand Prix - Sprint [v3.3.1]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# ...

# %%
#membuat objek untuk memudahkan visualisasi dengan modul fastf1
miamigp_rViz=vizTemplates.vizDataRace(miamigp_r)
miamigp_rLSViz=vizTemplates.vizDataRace(miamigp_rLS)
miamigp_qViz=vizTemplates.vizDataQuali(miamigp_q)
miamigp_qLSViz=vizTemplates.vizDataQuali(miamigp_qLS)
miamigp_sViz=vizTemplates.vizDataRace(miamigp_s)
miamigp_sqViz=vizTemplates.vizDataQuali(miamigp_sq)
# Out:
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# /Users/nendra/f1analytics/src/f1analytics/vizHelper/vizTemplates.py:300: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   tyreAlphas = pd.concat(
# getting and enriching fastest laps telemetry...
# getting and enriching all laps telemetry...
# /Users/nendra/f1analytics/src/f1analytics/vizHelper/vizTemplates.py:300: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   tyreAlphas = pd.concat(

# %% [markdown]
# <H3><strong>Norris berhasil mempertahankan ban medium saat awal Stint, sehingga dapat memaksimalkan ban Hard di Stint Terakhir</strong></H3>

# %%
miamigp_rViz.TyreStrats()

# %% [markdown]
# <ul>
# <li>
# Dengan memaksimalkan penggunaan ban Medium di stint awal, Norris dapat melakukan "pemborosan" di stint terakhir dengan ban Hardnya, sementara Verstappen dan Leclerc perlu menghemat ban Hardnya</li>
#
# <li>
# Meski Perez berhenti 2 kali, tapi masih bisa mempertahankan posisinya dibanding pembalap lain dibelakangnya yang melakukan 2 kali pit stop
# </li>
# </ul>
#
# <p>

# %% [markdown]
# <H3><strong>Kelompok teratas saat sesi Sprint berubah drastis dibandingkan dengan saat Race</H3></strong>

# %%
#cluster pengelompokan saat sprint
miamigp_sViz.clusterAnalysis(min_samp=3,epsVar=0.55,clusterNames=['Backmarkers','Midfield Bawah','Dominator','Midfield Atas'])

# %%
#cluster pengelompokan saat race
miamigp_rViz.clusterAnalysis(min_samp=2,epsVar=0.8,clusterNames=['Leaders','Backmarkers','Midfield'])

# %% [markdown]
# <ul>
# <li>
# Pada sesi Sprint, pembalap terbagi menjadi 4 kelompok. Kelompok teratas 'Dominator' adalah penghuni reguler (Verstappen, Perez dan Leclerc), sementara kelompok kedua teratas ada Piastri, Sainz dan yang mengagetkan: Ricciardo
# </li>
# <li>
# Tetapi saat sesi balapan, Kelompok kedua teratas langsung tergabung ke kelompok teratas, sedangkan Ricciardo 'turun kasta'. Hamilton menjad lebih cepat saat balapan dan membuat Hulkenberg dan Tsunoda menjadi  kelompok terbawah
# </li>
# </ul>
# <break>
# <break>

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Diantara para Leader, Norris mendominasi setiap segmen trek berkecepatan tinggi</strong></H3>

# %%
#menampilkan dominasi track
miamigp_rViz.trackDominance(['VER','NOR','LEC'])

# %% [markdown]
# <ul>
# <li>
# Norris menguasai semua segmen trek berkecepatan tinggi, dan tetap berhasil menguasai satu tikungan 17 yang berkecepatan rendah.
# </li>
# <li>
# Tikungan berkecepatan rendah biasanya dikuasai oleh Ferrari, tetapi di balapan ini Ferrari hanya menguasai 1 tkungan lambat (6,7,8). Tetapi menguasai 1 tikungan chicane medium
# </li>
# <li>
# Walaupun dengan kesultannya dengan ban mobil serta kerusakan sayap depannya, Verstappen masih dapat mendominasi beberapa tkungan berkecepatan tinggi dan tikungan yang sangat teknikal
# </li>
# <ul>

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Norris melakukan "Lift and Coast" pada Stint Pertama tetapi tetap mempertahankan pacenya</strong><H3>

# %%
#menampilkan chart degradasi ban
miamigp_rViz.TyreDeg(['VER','NOR','LEC','HAM','PIA','RUS','PER'])

# %% [markdown]
# <ul>
# <li>
# Mercedes menunjukkan perkembangan dalam  degradasi bannya, terutama Hamilton yang penggunaan Ban Hardnya sangat efisien. Tetapi masih belum lebih efisien dibandingkan Red Bull, McLaren, dan Ferrari</li>
# <li>
# Penggunaan ban medium Piastri sangat tidak efisien di Stint Terakhir.</li>
# </ul>

# %%
#menampilkan perhitungan durasi tancap gas
miamigp_rViz.ThrottleViz(['VER','NOR','LEC'])
# Out:
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Y' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'Z' while merging telemetry.
# WARNING:fastf1.fastf1.core:Failed to preserve data type for column 'X' while merging telemetry.
# ...

# %% [markdown]
# <li>Norris kemungkinan menggunakan strategi 'Lift and Coast' pada stint pertamanya untuk menghemat penggunaan ban mediumnya, sehingga dapat memaksimalkan penggunaan ban hard di stint terakhir. Walaupun begitu, Norris masih dapat mempertahankan pacenya</li

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Verstappen melambat dari sebelum menabrak Cone/Bollard, Norris menjadi lebih cepat setelah SC</H3></strong>

# %%
#menampilkan grafik laptime LEC,NOR,VER
miamigp_rViz.LinePlot(['VER','NOR','LEC'])

# %% [markdown]
# <ul>
# <li>
# Pada Lap 21, Verstappen menabrak Cone yang menyebabkan VSC dikeluarkan. Floor Verstappen juga mengalami kerusakan ringan disini
# </li>
# <li>
# Tetapi apabila dilihat dari grafik, Verstappen sudah mulai menjadi lebih lambat dibanding Leclerc dan Norris sejak Lap 18. Yang berarti Verstappen memang kesulitan mengendalikan mobilnya bahkan sebelum menabrak cone
# </li>
# <li>
# Menariknya, setelah VSC Norris malah jadi lebih cepat dibandingkan dengan Leclerc yang sudah pit untuk ban Hardnya di Lap 18. Dan saat ada SC di lap 28, Norris berhasil mengambil kesempatan tersebut untuk pit dan mengalahkan Verstappen dan Leclerc sampai akhir balapan
# </li>

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Verstappen tidak mendapatkan DRS sama sekali selama balapan</strong><H3>

# %%
#menampilkan grafik pertambahan DRS
miamigp_rViz.drsGain()

# %%
#menampilkan jarak VER dengan NOR 2 lap setelah SC yang tidak berada dibawah threshold DRS
test=miamigp_rViz.all_laps[(miamigp_rViz.all_laps['drvName']=='VER')&(miamigp_rViz.all_laps['LapNumber'].isin(range(33,40)))][['DistanceToDriverAhead','LapNumber','RelativeDistance','Distance','SessionTime','Time']]
#90m after t8
#70m+t16
#15+t17
#test=test.merge(miamigp_r.get_circuit_info().corners, on='Distance')
actZone=miamigp_r.get_circuit_info().corners
actZone=actZone[actZone['Number'].isin([8,16,17])]
actZone['drs']=actZone['Distance']+[100,70,200]
fig,ax=plt.subplots(figsize=(11,7))
sns.lineplot(data=test,x='Distance',y='DistanceToDriverAhead',hue='LapNumber',ax=ax,palette=sns.color_palette("crest", as_cmap=True))
for i,rows in actZone.iterrows():
    ax.axvline(rows['drs'],color='purple')
    ax.text(rows['drs']+50,0,f'Zona Deteksi DRS',rotation=90,fontsize=8.5,verticalalignment='bottom')
ax.axhline(60,color='blueviolet')
ax.text(-250,50,'Threshold DRS',ha='left')
ax.set_ylim(0,300)
ax.set_ylabel('Jarak ke Norris (meter)')
ax.set_xlabel('Tikungan ke-')
ax.set_xticks(miamigp_r.get_circuit_info().corners['Distance'])
ax.set_xticklabels(miamigp_r.get_circuit_info().corners['Number'])
    #ax.axvline(rows['Distance'],color='yellow')
# Out:
# [Text(369.8314370879182, 0, '1'),
#  Text(471.29481946249575, 0, '2'),
#  Text(566.29362266354, 0, '3'),
#  Text(1136.1666522854389, 0, '4'),
#  Text(1254.2749087143848, 0, '5'),
#  Text(1399.2232879703206, 0, '6'),
#  Text(1542.6807390678794, 0, '7'),
#  Text(1640.7801870300088, 0, '8'),
#  Text(2172.1009011830643, 0, '9'),
#  Text(2428.538488510676, 0, '10'),
#  Text(3086.6125517363485, 0, '11'),
#  Text(3199.67709375367, 0, '12'),
#  Text(3326.3178422801907, 0, '13'),
#  Text(3406.1367809088065, 0, '14'),
#  Text(3421.5237889837144, 0, '15'),
#  Text(3519.79132225735, 0, '16'),
#  Text(4829.561724145655, 0, '17'),
#  Text(4976.055035415367, 0, '18'),
#  Text(5179.148343378158, 0, '19')]

# %% [markdown]
# <li>
# Ketika sesi SC berakhir, Verstappen tidak dapat mengejar Norris sehingga Verstappen tidak mendapatkan kesempatan DRS sekalipun
# </li>
# <li>
# Karena kerusakan front wing di Lap 21, top speed Verstappen di balapan ini juga hanya 322kpj, paling rendah diantara pembalap lain. Sehingga terlihat Verstappen mulai tertinggal dari Norris di setiap segmen berkecepatan tinggi (Setelah Tikungan 8 dan Tikungan 16)
# </li>

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Pace Leader saat Race lebih lambat dibandingan dengan Sprint

# %%
#membuat perhitungan perbedaan rata-rata waktu antara sprint dengan race
import math
result={}
for drvs in miamigp_r.drivers:
    #fig,ax=plt.subplots()
    drv=miamigp_r.get_driver(drvs).Abbreviation
    tcolors='#'+miamigp_r.get_driver(drv).TeamColor
    test=miamigp_r.laps.pick_driver(drv).pick_accurate().pick_wo_box()[['LapTime','LapNumber']]
    test=test[test['LapNumber']>(57-17)]
    #test.plot(x='LapNumber',y='LapTime',ax=ax,label='RACE',color=tcolors)
    x=miamigp_s.laps.pick_driver(drv).pick_wo_box()[['LapTime','LapNumber']]
    x['LapNumberAdjusted']=x['LapNumber']+(57-19)
    df_sr=test.merge(x,left_on='LapNumber',right_on='LapNumberAdjusted',suffixes=['_race','_sprint'])[['LapTime_race','LapTime_sprint']]
    df_sr['gap']=df_sr['LapTime_race']-df_sr['LapTime_sprint']
    
    #x.plot(x='LapNumberAdjusted',y='LapTime',ax=ax,label='SPRINT',color=tcolors,linestyle=':')
    sec=df_sr['gap'].median().total_seconds()
    if math.isnan(sec)!=True:
        result[drv]=sec

# %%
#menampilkan hasil perhitungan
df=pd.DataFrame(result,index=[0]).T.sort_values(0,ascending=False)
sns.set_theme(rc={'figure.figsize':(15,9)})
fastf1.plotting.setup_mpl()
g=sns.barplot(data=df,x=0,y=df.index,hue=0,order=df.index[::-1],palette=sns.color_palette("coolwarm", as_cmap=True),legend=False)

for index, row in df.iterrows():
    if row[0]<0:
        g.text( row[0], index, round(row[0],3), color='white', ha="right")
    else:
        g.text( row[0], index, '+'+str(round(row[0],3)), color='white', ha="left")

g.set_ylabel('Pembalap')
g.set_xlabel('Rata-rata perbedaan waktu Race (17 Lap terakhir) dengan Sprint')
g.grid(c='grey')
g.set_title('Rata-Rata Pace Race (17 Lap terakhir) vs Sprint')
# Out:
# Text(0.5, 1.0, 'Rata-Rata Pace Race (17 Lap terakhir) vs Sprint')

# %% [markdown]
# <li>Kedua pebalap yang menduduki posisi leader yaitu Verstappen dan Leclerc, memiliki pace yang lebih lambat saat balapan dibandingkan saat Sprint</li>
# <li>
# Hamilton memiliki kenaikan pace yang sangat pesat dibandingkan pada saat Sprint. Lebih cepat hampir satu detik
# </li>
# <li>
# Meski memiliki performa yang bagus saat Race, Ricciardo mengalami penurunan pace yang sangat besar dibandingkan saat Sprint
# </li>

# %% [markdown]
# <p>

# %% [markdown]
# <H3><strong>Mobil Lando Sudah Dipasang Banyak Upgrade Baru di balapan Miami ini

# %%
#menghitung upgrade dari masing-masing tim
upgrades={ 'drivers':['VER','NOR','ALO','HAM','LEC','OCO','ALB','TSU','BOT','HUL'],'Banyaknya Upgrade':[1,10,5,4,0,0,1,2,2,1]}
upgrades=pd.DataFrame(upgrades)
upgrades['Tim']=upgrades['drivers'].apply(lambda x: miamigp_r.get_driver(x).TeamName)
g=sns.barplot(data=upgrades,x='Tim',y='Banyaknya Upgrade',hue='Banyaknya Upgrade',legend=False,palette=sns.color_palette("flare", as_cmap=True))
for i,row in upgrades.iterrows():
    g.text(row['Tim'],row['Banyaknya Upgrade']+0.1,row['Banyaknya Upgrade'],color='white',ha='center')
plt.xticks(rotation=45,ha='right')
g.set_title('Banyaknya Upgrade per Tim')
# Out:
# Text(0.5, 1.0, 'Banyaknya Upgrade per Tim')

# %% [markdown]
# <li>Pada balapan ini, McLaren mampu menambah 10 upgrade yang tadinya direncanakan untuk dipasang di balapan selanjutnya, tetapi dapat dipasang dalam balapan ini</li>
# <li>
# RedBull hanya melakukan 1 perubahan, sedangkan Ferrari tidak sama sekali</li>

# %% [markdown]
# <p>

# %% [markdown]
# <H2>Recap:</H2>
# <ul>
# <li>
# Meskipun ada sesi Safety Car dan kesulitan Verstappen yang menguntungkan Norris, tetapi tanpa manajemen ban yang baik dan upgrade dari McLaren kesempatan Norris menjadi juara sangat kecil
# </li>
# <li>
# Performa Mercedes sudah mulai membaik, akan tetapi masih belum mampu menyaingi para Leaders. Russell belum bisa mengimbangi Hamilton</li>
# <li>
# RedBull dan Ferrari tidak begtu menunjukkan taringnya di balapan ini. Kemungkinan karena belum adanya upgrade yang signifikan
# </li>
#
# <H4><strong>
# Akankah McLaren mampu mempertahankan tekanan ini kepada para leaders di balapan selanjutnya? atau RedBull dan Ferrari akan menunjukkan taringnya kembali?
